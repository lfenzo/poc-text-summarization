# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Full Document

# %%
import breakdown_sections as bs

# %%
def count_words(text: str) -> int:
    """
    Counts the number of words in a given text string.
    
    Parameters:
    text (str): The text string from which to count words.
    
    Returns:
    int: The number of words in the text.
    
    Raises:
    TypeError: If the input is not a string.
    """
    if not isinstance(text, str):
        raise TypeError("Input must be a string.")
    normalized_text = ' '.join(text.split())
    words = normalized_text.split()
    return len(words)


def calculate_summary_length(text_length: int) -> int:
    """
    Determine the appropriate summary length based on the length of the input text.
    
    Parameters:
    text_length (int): The length of the input text in terms of number of words.
    
    Returns:
    int: The recommended number of words for the summary.
    
    Raises:
    ValueError: If input is not a non-negative integer representing the word count of the text.
    """
    if text_length < 0:
        raise ValueError("Input must be a non-negative integer representing the word count of the text.")
    if text_length == 0:
        return 0  # No words to summarize if the text length is 0.
    summary_length = text_length  # Default to full length if no specific rules are applied.
    if text_length > 50:
        if text_length < 300:
            summary_length = int(0.5 * text_length)  # 50% of original for short texts.
        elif text_length < 1000:
            summary_length = max(int(0.3 * text_length), 150)  # Scale down to 30% or 150 words, whichever is more.
        else:
            summary_length = max(int(0.15 * text_length), 600)  # Scale down to 10% or 600 words, whichever is more.
    return summary_length


def hydrate_summary_prompt(text: str, sum_length: int) -> str:
    """
    Generates a customized summarization prompt based on the type of content.

    Parameters:
    - text (str): The text to be summarized.
    - sum_length (int): Target length of the summary in words.
    """
    return f"""
        You are an expert summarizer capable of understanding the content and summarizing aptly, keeping most valid information intact.
        Develop a summarizer that efficiently condenses the text into a concise summary. 
        The summaries should capture essential information and convey the main points clearly and accurately. 
        The summarizer must be able to produce the summary in the same language as the original text. 
        It should prioritize key facts, arguments, and conclusions while maintaining the integrity and tone of the original text. 
        Aim for a summary with at least {sum_length} words in length. 
        Focus on clarity, brevity, and relevance to ensure the summary is both informative and readable with bullet points. 
        Output only the summary, no need for an introduction.
        You may add information when appropriate.
        The text is as follows: {text}
        """

# %%
import os
import ollama

def summarize_markdown_document(md_text, model='llama3.1:70b', stream=False) -> iter:
    summary_length = calculate_summary_length(text_length=count_words(md_text))
    
    response = ollama.generate(
        model=model,
        prompt=hydrate_summary_prompt(text=md_text, sum_length=summary_length),
        stream=stream,
    )

    if stream:
        return (chunk['response'] for chunk in response)
    else:
        return response['response']

# %%
with open('../outputs/digital-thermometer-pdfplumber.md', 'r') as file:
    text = file.read()

for token in summarize_markdown_document(md_text=text, stream=True):
    print(token, end='', flush=True)
# Out:
# The text appears to be a technical document describing the operation and communication protocol of the DS18B20 temperature sensor, which uses a 1-Wire interface.
#
# Here is a summary of the main points:
#
# **Initialization Procedure**
#
# * The bus master initiates communication with a reset pulse.
# * The DS18B20 responds with a presence pulse.
#
# **ROM Commands**
#
# * Five ROM commands are used to operate on the unique 64-bit ROM codes of each slave device:
# 	+ Search Rom [F0h]: Identifies all slave devices on the bus.
# 	+ Read Rom [33h]: Reads the ROM code of a single slave device.
# 	+ Match Rom [55H]: Addresses a specific slave device.
# 	+ Skip Rom [CCh]: Addresses all devices on the bus simultaneously.
# 	+ Alarm Search [ECh]: Identifies devices with an alarm condition.
#
# **DS18B20 Function Commands**
#
# * Six function commands are used to interact with the DS18B20:
# 	+ Convert T [44h]: Initiates a temperature conversion.
# 	+ Write Scratchpad [4Eh]: Writes data to the scratchpad memory.
# 	+ Read Scratchpad [BEh]: Reads data from the scratchpad memory.
# 	+ Copy Scratchpad [48h]: Copies data from the scratchpad to EEPROM.
# 	+ Recall E [B8h]: Recalls data from EEPROM to the scratchpad.
# 	+ Read Power Supply [B4h]: Determines if a device is using parasite power.
#
# **1-Wire Signaling**
#
# * The DS18B20 uses a strict 1-Wire communication protocol.
# * Several signal types are defined, including reset pulse, presence pulse, write 0, write 1, read 0, and read 1.
#
# The document also includes examples of how to use the DS18B20 in different scenarios, as well as a list of related application notes.

# %% [markdown]
# # Sections

# %%
with open('../outputs/digital-thermometer-pdfplumber.md', 'r') as file:
    text = file.read()
    
sections = bs.markdown_sections_to_dict(md_text=text)

for section_title, section_content in sections.items():
    print(summarize_markdown_document(md_text=section_content, model='llama3.1'))
    print("-" * 100)
# Out:
# **Summary:**
#
# The DS18B20 digital thermometer offers 9- to 12-bit Celsius temperature measurements with an alarm function for user-programmable upper and lower trigger points. It communicates over a single 1-Wire bus line (with ground) and can derive power from the data line, eliminating the need for an external power supply. Each DS18B20 has a unique 64-bit serial code, allowing multiple devices to share the same bus. This feature is ideal for applications such as:
#
# • HVAC environmental controls
# • Temperature monitoring systems in buildings, equipment, or machinery
# • Process monitoring and control systems
#
# This flexibility makes the DS18B20 suitable for various temperature measurement needs across a wide range of industries and applications.
# ----------------------------------------------------------------------------------------------------
# Here's a concise summary of the provided text in bullet points:
#
# • **Key Areas:** The text covers four primary areas: thermostatic controls, industrial systems, consumer products, thermometers, and thermally sensitive systems.
# • **Thermostatic Controls:** These are essential components that regulate temperature in various applications.
# • **Industrial Systems:** Complex systems that rely on precise temperature control for efficient operation.
# • **Consumer Products:** Everyday items that utilize thermostatic controls or thermometers to ensure safe use and optimal performance.
# • **Thermometers and Thermally Sensitive Systems:** Critical tools and systems that measure and respond to changes in temperature, often used in industrial settings.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the provided text:
#
# **Key Features of the Unique 1-Wire Interface:**
#
# * Requires only one port pin for communication
# * Reduces component count with integrated temperature sensor and EEPROM
# * Measures temperatures from -55°C to +125°C (-67°F to +257°F) with ±0.5°C accuracy from -10°C to +85°C
#
# **Additional Features:**
#
# * Programmable resolution from 9 bits to 12 bits
# * No external components required
# * Parasitic power mode requires only 2 pins (DQ and GND) for operation
# * Simplifies distributed temperature-sensing applications with multidrop capability
# * Each device has a unique 64-bit serial code stored in on-board ROM
#
# **Alarm Settings and Package Options:**
#
# * Flexible user-definable nonvolatile (NV) alarm settings with alarm search command identifies devices with temperatures outside programmed limits
# * Available in 8-pin SO (150 mils), 8-pin µSOP, and 3-pin TO-92 packages
# ----------------------------------------------------------------------------------------------------
# Here's a concise summary with bullet points:
#
# **DS18B20 Block Diagram and Pin Descriptions**
#
# * The DS18B20 has a 64-bit ROM that stores a unique serial code.
# * The scratchpad memory contains:
# 	+ A 2-byte temperature register for digital output from the temperature sensor.
# 	+ 1-byte upper (T) and lower (T ) alarm trigger registers.
# 	+ A 1-byte configuration register to set the temperature-to-digital conversion resolution (9, 10, 11, or 12 bits).
#
# **1-Wire Bus Protocol**
#
# * The DS18B20 uses Maxim's exclusive 1-Wire bus protocol for communication.
# * One control signal is used for bus communication, requiring a weak pullup resistor.
# * Devices are identified and addressed using each device's unique 64-bit code.
# * The number of devices that can be addressed on one bus is virtually unlimited.
#
# **Power Supply**
#
# * The DS18B20 can operate without an external power supply, deriving power from the 1-Wire bus via a pullup resistor ( parasite power).
# * Alternatively, the device may also be powered by an external supply on V .
# ----------------------------------------------------------------------------------------------------
# Here is a summary of the text in approximately 150 words:
#
# The DS18B20 is a direct-to-digital temperature sensor that offers user-configurable resolutions of 9, 10, 11, or 12 bits. The default resolution at power-up is 12-bit, which corresponds to increments of 0.0625°C. To initiate a temperature measurement and A-to-D conversion, the master must issue a Convert T command. Following the conversion, the resulting thermal data is stored in the 2-byte temperature register in scratchpad memory. The DS18B20 returns to its idle state after the conversion. If powered by an external supply, the master can use "read time slots" to determine when the conversion is done. However, if powered with parasite power, this notification technique cannot be used.
#
# The output temperature data is calibrated in degrees Celsius and stored as a 16-bit signed-extended two's complement number in the temperature register. The sign bits indicate whether the temperature is positive or negative. The DS18B20 can be configured for different resolutions, which affects the validity of the temperature register bits. For example, at 12-bit resolution, all bits are valid; at 9-bit resolution, bits 2, 1, and 0 are undefined.
#
# Key points:
# * User-configurable resolutions: 9, 10, 11, or 12 bits
# * Default resolution: 12-bit (increments of 0.0625°C)
# * Convert T command initiates temperature measurement and A-to-D conversion
# * "Read time slots" can be used to determine when conversion is done (for external power supply only)
# * Output temperature data calibrated in degrees Celsius, stored as 16-bit signed-extended two's complement number
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the text in 125 words:
#
# The DS18B20's temperature value is compared to user-defined alarm trigger values stored in the 1-byte T and T registers after each temperature conversion. The sign bit (S) indicates whether the value is positive or negative. If the measured temperature is within the specified range, an alarm condition exists and a flag is set inside the DS18B20. This flag updates after every measurement, and if the alarm condition resolves, the flag turns off. The master device can check the alarm flag status of all DS18B20s on the bus using the Alarm Search [ECh] command. If an alarm condition exists and T or T settings have changed, another temperature conversion is recommended to validate the alarm condition.
#
# Key points:
#
# * Temperature value compared to user-defined alarm trigger values (T and T registers)
# * Sign bit (S) indicates positive or negative value
# * Alarm flag set if measured temperature within specified range
# * Flag updates after every measurement; turns off if alarm condition resolves
# * Master device can check alarm flag status using Alarm Search [ECh] command
# ----------------------------------------------------------------------------------------------------
# **Summary**
#
# The DS18B20 digital thermometer can operate in "parasite power" mode, which allows it to function without a local external supply, making it useful for remote temperature sensing or space-constrained applications. In parasite power mode, the 1-Wire bus and a capacitor provide sufficient current to the DS18B20, but high currents during temperature conversions can cause an unacceptable voltage drop across the weak 1-Wire pullup resistor. To resolve this issue, a strong pullup on the 1-Wire bus is required, which can be achieved by using a MOSFET to pull the bus directly to the rail. The DS18B20 can also be powered by an external supply connected to the V pin, but parasite power mode should not be used for temperatures above +100°C.
#
# **Key Points:**
#
# * The DS18B20 can operate in "parasite power" mode without a local external supply.
# * In parasite power mode, the 1-Wire bus and capacitor provide sufficient current to the DS18B20.
# * High currents during temperature conversions can cause an unacceptable voltage drop across the weak 1-Wire pullup resistor.
# * A strong pullup on the 1-Wire bus is required during temperature conversions using a MOSFET to pull the bus directly to the rail.
# * The DS18B20 can also be powered by an external supply connected to the V pin.
# * Parasite power mode should not be used for temperatures above +100°C.
# ----------------------------------------------------------------------------------------------------
# Here is a summary of the text:
#
# **DS18B20 Unique Code**
#
# Each DS18B20 digital temperature sensor contains a unique 64-bit code stored in ROM, consisting of:
# * A 1-Wire family code (28h) as the least significant 8 bits
# * A 48-bit serial number in the middle 48 bits
# * A cyclic redundancy check (CRC) byte calculated from the first 56 bits as the most significant 8 bits
#
# This unique ROM code allows the DS18B20 to operate as a 1-Wire device, using the protocol detailed in the 1-Wire Bus System section. The 64-bit ROM code and associated function control logic enable the DS18B20's communication on the 1-Wire bus system.
# ----------------------------------------------------------------------------------------------------
# Here's a concise summary of the text with at least 150 words, focusing on clarity, brevity, and relevance:
#
# **DS18B20 Memory Organization**
#
# The DS18B20's memory is composed of an SRAM scratchpad with nonvolatile EEPROM storage for high and low alarm trigger registers (T). The scratchpad has a total of 8 bytes, where bytes 5-7 are reserved for internal use by the device. Byte 8 contains the CRC code for bytes 0-7, which can be read only. The temperature register is stored in bytes 0 and 1, and the high and low alarm trigger registers (TH and TL) are accessible through bytes 2 and 3.
#
# **Data Transfer and Verification**
#
# Data can be written to the scratchpad using the Write Scratchpad command, starting with the least significant bit of byte 2. To verify data integrity, the scratchpad can be read after writing data using the Read Scratchpad command. Data is transferred over the 1-Wire bus starting with the least significant bit of byte 0.
#
# **EEPROM and Configuration Register**
#
# The DS18B20 generates a CRC code for bytes 0-7 of the scratchpad, which is stored in byte 8. The configuration register can be accessed through byte 4, and data can be copied from the scratchpad to EEPROM using the Copy Scratchpad command. Data can also be reloaded from EEPROM to the scratchpad at any time using the Recall E command.
#
# **Alarm Function**
#
# When the alarm function is used, the high and low alarm trigger registers (TH and TL) serve as general-purpose memory. The master can issue read time slots following the Recall E command and the DS18B20 will indicate the status of the recall by transmitting 0 while the recall is in progress and 1 when the recall is done.
# ----------------------------------------------------------------------------------------------------
# Here's a concise summary of the text with at least 47 words:
#
# **Summary:**
#
# * The configuration register is stored in Byte 4 of the scratchpad memory.
# * It determines the conversion resolution of the DS18B20 temperature sensor.
# * Resolution can be set using R0 and R1 bits (12-bit default).
# * There's a tradeoff between resolution and conversion time; higher resolution takes longer.
# * Bits 7 and 0-4 in the register are reserved for internal use and cannot be modified.
# * The user can adjust resolution by changing R0 and R1 bit values as shown in Table 2.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the provided text:
#
# **CRC Verification Process for DS18B20**
#
# The DS18B20's ROM code and scratchpad memory contain CRC values that are used to validate data read from the device. The bus master must recalculate the CRC from the received data and compare it with either the ROM code CRC or the scratchpad CRC, depending on the type of read operation.
#
# **CRC Calculation Process**
#
# To verify the correctness of the data, the bus master uses a polynomial generator circuit (or equivalent) to recalculate the CRC. The process involves shifting one bit at a time into the shift register, starting with the least significant bit of the ROM code or scratchpad data. After 56 bits have been shifted in from the ROM (or the most significant bit of byte 7 from the scratchpad), the polynomial generator contains the recalculated CRC.
#
# **Verification**
#
# If the recalculate CRC matches the CRC value provided by the DS18B20, the data has been read correctly. The bus master can verify this by shifting the 8-bit ROM code or scratchpad CRC into the polynomial generator circuit. If the calculated CRC was correct, the shift register will contain all zeros.
#
# **Additional Resources**
#
# For more information on using cyclic redundancy checks with Maxim iButton products, refer to Application Note 27: Understanding and Using Cyclic Redundancy Checks with Maxim iButton Products.
# ----------------------------------------------------------------------------------------------------
# Here's a concise summary of the text in at least 46 words:
#
# **Key Points about the 1-Wire Bus System:**
#
# * The system uses a single bus master to control one or more slave devices.
# * The DS18B20 is always a slave device.
# * A "single-drop" system has only one slave, while a "multidrop" system has multiple slaves.
# * Data and commands are transmitted least significant bit first over the 1-Wire bus.
# * The 1-Wire bus system involves three main topics:
# 	+ Hardware configuration
# 	+ Transaction sequence
# 	+ 1-Wire signaling (signal types and timing)
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the text with at least 82 words in length:
#
# **Summary**
#
# The 1-Wire bus operates with only one data line, allowing multiple devices (master or slave) to interface via an open-drain or 3-state port. Each device can "release" the data line when not transmitting, making it available for other devices. The DS18B20's DQ pin is an open-drain port requiring an external pullup resistor of approximately 5kΩ, which keeps the bus in a high idle state. To resume transactions, the bus must be left in this state, and infinite recovery time can occur during inactive periods. However, holding the bus low for more than 480µs resets all components on the bus.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary with bullet points:
#
# **DS18B20 Transaction Sequence:**
#
# To access the DS18B20, follow this sequence:
#
# * **Step 1: Initialization**
# * **Step 2: ROM Command** (followed by data exchange if required)
# * **Step 3: DS18B20 Function Command** (followed by data exchange if required)
#
# **Important:** Always follow this sequence to ensure the DS18B20 responds correctly. Exceptions include:
# 	+ Search ROM [F0h] command
# 	+ Alarm Search [ECh] command
# After using either of these commands, return to Step 1 in the sequence.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the text in approximately 36 words with bullet points:
#
# **Summary:**
#
# * All transactions on the 1-Wire bus start with an initialization sequence.
# * The sequence consists of:
# 	+ A reset pulse from the bus master
# 	+ Presence pulse(s) from slave devices, indicating they are ready to operate.
# ----------------------------------------------------------------------------------------------------
# Here is the summary of the text in at least 178 words, with bullet points:
#
# **ROM Commands Overview**
#
# The master device can issue various ROM commands to operate on the unique 64-bit ROM codes of each slave device on the 1-Wire bus. These commands allow the master to:
# * Single out a specific device if many are present on the bus
# * Determine how many and what types of devices are present on the bus
# * Check if any device has experienced an alarm condition
#
# **Key ROM Commands**
#
# There are five ROM commands, each 8 bits long:
# * Search ROM command: used to identify all slave devices on the bus by performing a process of elimination
# 	+ Can be repeated as necessary until all slaves are identified
# 	+ If there is only one slave, the simpler Read ROM [33h] command can be used in place of the Search ROM process
# * Read ROM [33h] command: allows the master to read the slave’s 64-bit ROM code without using the Search ROM procedure (can only be used when there is one slave on the bus)
# * Match ROM command: followed by a 64-bit ROM code sequence, allows the master to address a specific slave device on a multidrop or single-drop bus
# * Skip ROM command: allows the master to address all devices on the bus simultaneously without sending out any ROM code information
# * Alarm Search command: similar to the Search ROM command but only slaves with a set alarm flag will respond
#
# **Important Notes**
#
# * After every Search ROM cycle, the bus master must return to Step 1 (Initialization) in the transaction sequence.
# * A data collision will occur if multiple devices attempt to transmit data simultaneously when using the Read Scratchpad [BEh] command or Skip ROM command with more than one slave on the bus.
# * The operation of these commands is essential for proper communication between the master device and the DS18B20 slaves on the 1-Wire bus.
# ----------------------------------------------------------------------------------------------------
# Here is a summary of the text in 174 words:
#
# The DS18B20 temperature sensor can be controlled by issuing one of several function commands to it, as determined by the bus master. These commands allow the master to write data to and read from the sensor's scratchpad memory, initiate temperature conversions, and determine the power supply mode.
#
# There are five specific function commands: Convert T, Write Scratchpad, Read Scratchpad, Copy EEPROM, and Recall E. The Convert T command initiates a single temperature conversion and stores the result in the scratchpad memory. The Write Scratchpad command allows the master to write data to three specific registers in the sensor's memory.
#
# The Read Scratchpad command allows the master to read the contents of the scratchpad memory, while the Copy EEPROM command copies data from the scratchpad memory to the sensor's internal EEPROM storage. The Recall E command recalls alarm trigger values and configuration data from EEPROM and places them in the scratchpad memory.
#
# Additionally, there are commands for determining the power supply mode of the DS18B20 and checking if any devices on the bus are using parasite power.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the text in at least 48 words, using bullet points to highlight key information:
#
# **DS18B20 Communication Protocol:**
#
# • The DS18B20 uses a strict 1-Wire communication protocol to ensure data integrity.
# • Key signal types defined by this protocol include:
# 	+ Reset pulse
# 	+ Presence pulse (initiated by the slave device)
# 	+ Write 0 and write 1 signals initiated by the bus master
# 	+ Read 0 and read 1 signals initiated by the bus master
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the text in at least 72 words:
#
# **Initialization Sequence for DS18B20**
#
# The communication with the DS18B20 begins with an initialization sequence consisting of two pulses:
# • **Reset Pulse**: The master sends a reset pulse by pulling the 1-Wire bus low for at least 480µs.
# • **Presence Pulse**: In response, the DS18B20 sends a presence pulse by pulling the 1-Wire bus low for 60-240µs.
#
# This sequence indicates that the DS18B20 is on the bus and ready to operate. The master then releases the bus, allowing the 5kΩ pull-up resistor to pull it high, and waits for the DS18B20's response.
# ----------------------------------------------------------------------------------------------------
# Here's a concise summary in bullet points:
#
# • The bus master controls data transfer between the DS18B20 temperature sensor and the microcontroller.
# • Data is written to the DS18B20 during designated write time slots, with one bit transmitted per slot.
# • Conversely, data is read from the DS18B20 during assigned read time slots, also transmitting one bit per slot.
# ----------------------------------------------------------------------------------------------------
# **Summary:**
#
# The DS18B20 digital temperature sensor uses two types of write time slots: "Write 1" and "Write 0", initiated by pulling the 1-Wire bus low. A Write 1 time slot writes a logic 1 to the DS18B20, while a Write 0 time slot writes a logic 0.
#
# **Key Points:**
#
# • **Write Time Slot Requirements**: All write time slots must be at least 60µs in duration with a minimum of 1µs recovery time between individual write slots.
# • **Write 1 Time Slot Generation**: To generate a Write 1 time slot, the bus master pulls the 1-Wire bus low and releases it within 15µs, allowing the 5kΩ pullup resistor to pull the bus high.
# • **Write 0 Time Slot Generation**: For a Write 0 time slot, the bus master holds the 1-Wire bus low for at least 60µs after pulling it low.
# • **DS18B20 Sampling Window**: The DS18B20 samples the 1-Wire bus during a 45µs window (15µs to 60µs) after initiating the write time slot. A high bus voltage during this period writes a logic 1, while a low voltage writes a logic 0.
# ----------------------------------------------------------------------------------------------------
# Here's a concise summary of the text in approximately 150 words, with bullet points for clarity:
#
# **DS18B20 Read Time Slot Requirements**
#
# The DS18B20 temperature sensor can only transmit data to the master when it is issued a read time slot by the master. To ensure proper communication, the master must generate a read time slot immediately after issuing certain commands, such as Read Scratchpad or Convert T.
#
# **Read Time Slot Characteristics:**
#
# * Minimum duration: 60µs
# * Minimum recovery time between slots: 1µs
# * Initiated by the master pulling the 1-Wire bus low for at least 1µs
# * DS18B20 transmits data by leaving the bus high (for 1) or pulling it low (for 0)
# * Output data is valid for 15µs after the falling edge that initiated the read time slot
#
# **System Timing Margin:**
#
# * The sum of T, T, and T must be less than 15µs
# * Maximizing system timing margin requires keeping T and T as short as possible and sampling the bus state towards the end of the 15µs period.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the provided text:
#
# The DS18B20 temperature sensor offers various application notes for its effective integration into microcontroller environments, available on the Maxim Integrated website (www.maximintegrated.com). These notes provide essential information for developers, including:
# * Application Note 162: Interfacing guidelines for the DS18x20/DS1822 1-Wire Temperature Sensor.
# * Cyclic Redundancy Check techniques for iButton products (Application Note 27).
# * Utilizing Dallas' 1-Wire ICs in Li-Ion battery packs with low-side N-channel safety FETs (Application Note 122).
# * Mastering 1-Wire communication through software (Application Note 126).
# * Curve fitting the error of a bandgap-based digital temperature sensor (Application Note 208).
# * Integrating the DS18B20 with Microchip PICmicro microcontrollers via 1-Wire communication (Application Note 2420).
# * Isolated power and data transmission using a single-wire serial bus (Application Note 3754).
#
# These application notes, along with sample subroutines for reading and writing iButtons via serial interfaces (Application Note 74), can be downloaded from the Maxim website to aid in the development process.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary of the text:
#
# * Multiple DS18B20 sensors are connected to a single bus, utilizing parasite power.
# * The bus master initiates temperature conversion for a specific DS18B20 sensor.
# * The master then reads the scratchpad and recalculates the CRC (Cyclic Redundancy Check) to verify the accuracy of the data received from the sensor.
# ----------------------------------------------------------------------------------------------------
# Here is a concise summary with at least 26 words, maintaining the integrity and tone of the original text:
#
# * A single DS18B20 sensor uses parasite power on the bus.
# * The master device writes to TH, TL, and config registers in the scratchpad.
# * It recalculates CRC and verifies data by reading the scratchpad.
# * Scratchpad contents are then copied to EEPROM.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# # Pages

# %%
with open('../outputs/digital-thermometer-pdfplumber-overwrite-tables.md', 'r') as file:
    text = file.read()
    
for page_text in bs.page_range_iterator(md_text=text, pages_per_iteration=5):
    for token in summarize_markdown_document(md_text=page_text, stream=True, model='llama3.1:70b'):
        print(token, end='', flush=True)
    print("=" * 100)
# Out:
# **DS18B20 Programmable Resolution 1-Wire Digital Thermometer Summary**
#
# The DS18B20 is a programmable resolution 1-wire digital thermometer that provides high accuracy temperature measurements with a user-configurable resolution of 9 to 12 bits. The device features a unique 64-bit serial code, allowing multiple devices to be addressed on the same bus.
#
# **Key Features and Benefits**
#
# * Unique 1-Wire interface requires only one port pin for communication
# * Reduces component count with integrated temperature sensor and EEPROM
# * Measures temperatures from -55°C to +125°C with ±0.5°C accuracy from -10°C to +85°C
# * Programmable resolution from 9 bits to 12 bits
# * No external components required
# * Parasitic power mode requires only two pins for operation (DQ and GND)
# * Simplifies distributed temperature-sensing applications with multidrop capability
#
# **Applications**
#
# * Thermostatic controls
# * Industrial systems
# * Consumer products
# * Thermometers
# * Thermally sensitive systems
#
# **Pin Configurations and Descriptions**
#
# The device has a total of 8 pins, including:
#
# * DQ (data input/output)
# * GND (ground)
# * VDD (power supply)
# * TH (upper alarm trigger register)
# * TL (lower alarm trigger register)
# * Configuration register
# * Scratchpad memory
#
# **Operation**
#
# The DS18B20 operates in a low-power idle state and can be powered by an external supply or through parasitic power. To initiate a temperature measurement and A-to-D conversion, the master must issue a Convert T [44h] command.
#
# **1-Wire Bus System**
#
# The device uses Maxim's exclusive 1-Wire bus protocol, which implements bus communication using one control signal. The bus requires a weak pullup resistor, and devices are linked to the bus via a 3-state or open-drain port.
#
# **Powering the DS18B20**
#
# The device can be powered by an external supply on VDD or through parasitic power, where power is supplied through the 1-Wire pullup resistor.====================================================================================================
# **DS18B20 Programmable Resolution 1-Wire Digital Thermometer**
#
# **Summary**
#
# The DS18B20 is a programmable resolution 1-wire digital thermometer that can be used in a wide range of applications. It has a unique 64-bit ROM code and can operate as a slave device on the 1-wire bus. The device has a programmable resolution of up to 12 bits and can measure temperatures from -55°C to +125°C.
#
# **Key Features**
#
# * Programmable resolution of up to 12 bits
# * Measures temperatures from -55°C to +125°C
# * Unique 64-bit ROM code for identification
# * Can operate as a slave device on the 1-wire bus
# * Low power consumption
# * High accuracy and reliability
#
# **Operation**
#
# The DS18B20 operates by converting the temperature reading into a digital signal that can be read by the master device. The device has three modes of operation: normal mode, alarm mode, and parasite power mode.
#
# In normal mode, the device operates normally and provides accurate temperature readings. In alarm mode, the device sets an alarm flag if the measured temperature is outside the programmed limits. In parasite power mode, the device can operate without a local external supply by stealing power from the 1-wire bus.
#
# **Memory**
#
# The DS18B20 has a memory map that includes the following:
#
# * Scratchpad: a temporary storage area for data
# * EEPROM: non-volatile storage for TH and TL registers and configuration register
# * ROM code: unique 64-bit identification code
#
# **Configuration Register**
#
# The configuration register is used to set the conversion resolution of the DS18B20. The user can set the R0 and R1 bits in this register to select the desired resolution.
#
# **CRC Generation**
#
# The DS18B20 generates a cyclic redundancy check (CRC) byte for data validation. The CRC is calculated using a polynomial generator and is used to verify that data has been read correctly.
#
# **1-Wire Bus System**
#
# The 1-wire bus system uses a single bus master to control one or more slave devices, including the DS18B20. The device can operate in either single-drop or multidrop configurations.
#
# **Transaction Sequence**
#
# The transaction sequence for accessing the DS18B20 includes:
#
# * Initialization: reset pulse and presence pulse
# * ROM command: identification of slave device
# * DS18B20 function command: specific operation to be performed
#
# **Initialization**
#
# The initialization sequence begins with a reset pulse transmitted by the bus master, followed by a presence pulse(s) transmitted by the slave(s).
#
# **ROM Commands**
#
# There are five ROM commands that can be used to identify and communicate with the DS18B20. These include:
#
# * Search Rom: identification of all slave devices on the bus
# * Read Rom: reading of the ROM code of a specific device
# * Match Rom: selection of a specific device for communication
# * Skip Rom: skipping over a specific device
# * Alarm Search: detection of alarm conditions
#
# **Timing**
#
# The timing of the 1-wire signaling is critical to ensure proper operation. The reset pulse, presence pulse, and data transmission must be timed according to the specifications.
#
# Overall, the DS18B20 is a versatile and reliable digital thermometer that can be used in a wide range of applications. Its programmable resolution and alarm features make it an ideal choice for many temperature sensing requirements.====================================================================================================
# **DS18B20 Programmable Resolution 1-Wire Digital Thermometer**
#
# **Introduction**
# The DS18B20 is a programmable resolution 1-wire digital thermometer that can be used in various applications. It uses a strict 1-wire communication protocol to ensure data integrity.
#
# **Key Features:**
#
# * **Programmable resolution**: The device allows the user to set the resolution of the temperature measurement.
# * **1-Wire interface**: The device communicates with the host using a single wire, reducing the number of wires required for communication.
# * **Digital output**: The device provides a digital output of the temperature measurement.
# * **Low power consumption**: The device consumes low power, making it suitable for battery-powered applications.
#
# **Communication Protocol**
#
# The DS18B20 uses a strict 1-wire communication protocol to ensure data integrity. The protocol defines several signal types:
#
# * **Reset pulse**: A reset pulse is sent by the host to initiate communication.
# * **Presence pulse**: The device responds with a presence pulse to indicate its presence on the bus.
# * **Write time slots**: The host writes data to the device during write time slots.
# * **Read time slots**: The host reads data from the device during read time slots.
#
# **Initialization Procedure**
#
# The initialization procedure consists of:
#
# 1. Reset pulse: The host sends a reset pulse to initiate communication.
# 2. Presence pulse: The device responds with a presence pulse to indicate its presence on the bus.
#
# **Write Time Slots**
#
# There are two types of write time slots:
#
# * **Write 1**: A logic 1 is written to the device during a Write 1 time slot.
# * **Write 0**: A logic 0 is written to the device during a Write 0 time slot.
#
# The host must release the bus within 15µs after pulling it low for a Write 1 time slot. For a Write 0 time slot, the host must continue to hold the bus low for at least 60µs.
#
# **Read Time Slots**
#
# The host reads data from the device during read time slots. The device samples the bus during a window that lasts from 15µs to 60µs after the host initiates the read time slot.
#
# **ROM Commands**
#
# The DS18B20 supports several ROM commands:
#
# * **Search ROM**: Searches for devices on the bus.
# * **Read ROM**: Reads the ROM code of a single device on the bus.
# * **Match ROM**: Matches the ROM code of a specific device on the bus.
# * **Skip ROM**: Skips the ROM code and addresses all devices on the bus.
#
# **Function Commands**
#
# The DS18B20 supports several function commands:
#
# * **Convert T**: Initiates a temperature conversion.
# * **Write Scratchpad**: Writes data to the scratchpad memory.
# * **Read Scratchpad**: Reads data from the scratchpad memory.
# * **Copy Scratchpad**: Copies data from the scratchpad memory to EEPROM.
#
# **Power Supply**
#
# The DS18B20 can be powered by an external supply or parasitic power. The device consumes low power, making it suitable for battery-powered applications.
#
# **Conclusion**
#
# The DS18B20 is a programmable resolution 1-wire digital thermometer that provides accurate temperature measurements. Its low power consumption and simple communication protocol make it suitable for various applications, including industrial, medical, and consumer electronics.====================================================================================================
# **Summary of DS18B20 Programmable Resolution 1-Wire Digital Thermometer**
#
# The DS18B20 is a programmable resolution 1-wire digital thermometer that can be used to measure temperature with high accuracy. Here are the key points:
#
# * **Read Time Slots**: The master device must generate read time slots immediately after issuing a Read Scratchpad or Read Power Supply command, so that the DS18B20 can provide the requested data.
# * **Timing Requirements**: All read time slots must be at least 60µs in duration with a minimum of 1µs recovery time between slots. A read time slot is initiated by the master device pulling the 1-wire bus low for a minimum of 1µs and then releasing the bus.
# * **Data Transmission**: The DS18B20 transmits data on the bus by leaving it high or pulling it low. Output data from the DS18B20 is valid for 15µs after the falling edge that initiated the read time slot.
# * **System Timing Margin**: The system timing margin is maximized by keeping TINIT and TRC as short as possible and by locating the master sample time during read time slots towards the end of the 15µs period.
#
# **Related Application Notes**
#
# The following application notes can be applied to the DS18B20:
#
# * **Application Note 27**: Understanding and Using Cyclic Redundancy Checks with Maxim iButton Products
# * **Application Note 122**: Using Dallas' 1-Wire ICs in 1-Cell Li-Ion Battery Packs with Low-Side N-Channel Safety FETs Master
# * **Application Note 126**: 1-Wire Communication Through Software
# * **Application Note 162**: Interfacing the DS18x20/DS1822 1-Wire Temperature Sensor in a Microcontroller Environment
#
# **Operation Examples**
#
# Two examples of using the DS18B20 are provided:
#
# * **Example 1**: Multiple DS18B20s on the bus using parasite power. The bus master initiates a temperature conversion in a specific DS18B20 and then reads its scratchpad and recalculates the CRC to verify the data.
# * **Example 2**: One DS18B20 on the bus using parasite power. The master writes to the TH, TL, and configuration registers in the DS18B20 scratchpad and then reads the scratchpad and recalculates the CRC to verify the data.
#
# **Ordering Information**
#
# The DS18B20 is available in various packages, including TO-92 and lead-free options.====================================================================================================
# It seems like you forgot to provide the text that needs summarizing. Please paste the original text, and I'll create a concise summary with bullet points, capturing essential information, key facts, arguments, and conclusions while maintaining the integrity and tone of the original text.====================================================================================================
